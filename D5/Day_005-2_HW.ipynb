# %% [markdown]
# ## 讀取 txt 檔
# * 請讀取 [text file](https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt)
# * 懶人複製連結: https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt
#
# ### Hints: 使用 [Request](https://blog.gtwang.org/programming/python-requests-module-tutorial/) 抓取資料
# ### Hints: [字串分割](http://www.runoob.com/python/att-string-split.html)
# ### Hints: 例外處理: [Try-Except](https://pydoing.blogspot.com/2011/01/python-try.html)

# %% [markdown]
# # [作業目標]
# - 試著讀取網頁上的圖片連結清單, 再以清單中網址讀取圖片

# %% [markdown]
# # [作業重點]
# - 從網頁上讀取連結清單 (In[1], In[2])
# - 從清單網址讀取圖片 (In[6]~In[9], Out[6]~Out[9])

# %%
## 假如我們不想把資料載到自己的電腦裡?
# 把連結填入
target_url = 'https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt'

# %%
import requests
response = requests.get(target_url)
data = response.text

# 用 request 傳送回來的資料不會認得斷行符號
print(len(data))
data[0:100]
# Out:
# 784594
# 'n00015388_157\thttp://farm1.static.flickr.com/145/430300483_21e993670c.jpg\nn00015388_238\thttp://farm2'

# %%
# 找到換行符號，用該符號做字串分割後，把它拿掉
split_tag = '\n'

arrange_data = data.split(split_tag)
print(len(arrange_data))
arrange_data = list(map(lambda x: x.split('\t')[-1], arrange_data))
# Out:
# 9996
# ['http://farm1.static.flickr.com/145/430300483_21e993670c.jpg', 'http://farm2.static.flickr.com/1005/3352960681_37b9c1d27b.jpg', 'http://farm1.static.flickr.com/27/51009336_a9663af3dd.jpg', 'http://farm4.static.flickr.com/3025/2444687979_bf7bc8df21.jpg', 'http://img100.imageshack.us/img100/3253/forrest004fs9.jpg', 'http://img172.imageshack.us/img172/4606/napo03072en9.jpg', 'http://fotootjesvanannelies.web-log.nl/olifantfotootjes/images/2008/06/04/img_8870.jpg', 'http://www.deweekkrant.nl/images/library/pictures/4f/2e/a5/cf/2_3d81b762a5e8a345bbb1f0884fab2e9762146129.jpg', 'http://www.porschemania.it/discus/messages/815/102099.jpg', 'http://farm1.static.flickr.com/72/225029238_805b0937ca.jpg', 'http://farm2.static.flickr.com/1128/1432436038_6c131f1bb0.jpg', 'http://farm4.static.flickr.com/3217/2942611930_d68204f726.jpg', 'http://farm1.static.flickr.com/29/54608382_ee8bd4f7fa.jpg', 'http://www.dierentuin.nl/images/jongengiraffe.jpg', 'http://farm4.static.flickr
d2f91246.jpg', 'http://media.zobrabant.nl:81/img/dyn/c1df79c81185d378ca5b284480961e46_200x131.jpg', 'http://farm1.static.flickr.com/71/214363343_126928340e.jpg', 'http://www.digi-irma.nl/fotos/dieren2/dier5.JPG', 'http://farm2.static.flickr.com/1406/674804962_882dc24bee.jpg', 'http://www.dongettyphoto.com/kenya/images/Reticulated-Giraffe.jpg', 'http://www.controcorrentesatirica.com/fotoarticoli/agnello.jpg', 'http://www.tvoggisalerno.it/Upload/Chicco.jpg', 'http://farm3.static.flickr.com/2087/2113639488_81e8734c2c.jpg', 'http://fotootjesvanannelies.web-log.nl/dierentuinfotootjes/images/img_1192_europa_aapjes.jpg', 'http://farm3.static.flickr.com/2022/2074347390_2a923cc9d7.jpg', 'http://www.corsaridelgusto.eu/wp/wp-content/uploads/2008/11/ochetta-tolosa.jpg', 'http://www.ieenn.com/Article/UploadFiles ...

# %% [markdown]
# ## 將 txt 轉成 pandas dataframe

# %%
import pandas as pd

df = pd.DataFrame({ 'image_url': arrange_data })
df.head()
# Out:
#                                            image_url
# 0  http://farm1.static.flickr.com/145/430300483_2...
# 1  http://farm2.static.flickr.com/1005/3352960681...
# 2  http://farm1.static.flickr.com/27/51009336_a96...
# 3  http://farm4.static.flickr.com/3025/2444687979...
# 4  http://img100.imageshack.us/img100/3253/forres...

# %% [markdown]
# ## 讀取圖片，請讀取上面 data frame 中的前 5 張圖片

# %%
from PIL import Image
from io import BytesIO
import numpy as np
import matplotlib.pyplot as plt

# 請用 df.loc[...] 得到第一筆資料的連結
first_link = df.loc[0]['image_url']
print(first_link)

response = requests.get(first_link)
img = Image.open(BytesIO(response.content))

# Convert img to numpy array

plt.imshow(img)
plt.show()
# Out:
# http://farm1.static.flickr.com/145/430300483_21e993670c.jpg

# %%
def img2arr_fromURLs(url_list, resize = False):
    image_list = []
    for url in url_list:
        try:
            response = requests.get(url)                    
            img = Image.open(BytesIO(response.content))
            image_list.append(img)
        except:
          print(url)
    """
    請完成這個 Function
    Args
        - url_list: list of URLs
        - resize: bool
    Return
        - list of array
    """
    
    return image_list

# %%
result = img2arr_fromURLs(df[0:5]['image_url'].values)
print(result)
print("Total images that we got: %i " % len(result)) # 如果不等於 5, 代表有些連結失效囉

for im_get in result:
    plt.imshow(im_get)
    plt.show()
# Out:
# http://img100.imageshack.us/img100/3253/forrest004fs9.jpg
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=499x435 at 0x11506ACD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x322 at 0x1157AFC50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=375x500 at 0x1100B7150>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375 at 0x1153A2290>]
# Total images that we got: 4
